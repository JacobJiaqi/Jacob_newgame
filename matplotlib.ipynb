# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import *
# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
matplotlib.__version__
# Out:
# '2.2.2'

# %% [markdown]
# ## histogram

# %%
np.random.seed(1)
mu,sigma = 100,15
x = mu+sigma *np.random.randn(10000)
n,bins,patches= plt.hist(x,bins=50,normed=1,facecolor='b',alpha=0.5)
print('n=',n)
print('bins=',bins)
plt.xlabel('smarts')
plt.ylabel('probability')
plt.title('Histogram of IQ')
plt.text(60,.025,r'$\mu=100,\ \sigma=15$')
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# n= [4.33841975e-05 0.00000000e+00 1.73536790e-04 2.16920987e-04
#  1.73536790e-04 5.63994567e-04 1.04122074e-03 9.11068147e-04
#  1.47506271e-03 2.55966765e-03 3.38396740e-03 4.59872493e-03
#  4.94579851e-03 7.98269233e-03 9.41437085e-03 1.17137333e-02
#  1.45337061e-02 1.48807797e-02 1.95662731e-02 2.31237772e-02
#  2.18222513e-02 2.39480770e-02 2.62908237e-02 2.71585076e-02
#  2.69849708e-02 2.69849708e-02 2.37311560e-02 2.37311560e-02
#  2.03471886e-02 1.77441368e-02 1.50109323e-02 1.34924854e-02
#  9.80482863e-03 8.15622912e-03 7.67900295e-03 6.07378764e-03
#  3.99134617e-03 3.55750419e-03 1.90890469e-03 1.30152592e-03
#  8.67683949e-04 5.63994567e-04 5.63994567e-04 1.30152592e-04
#  2.60305185e-04 1.73536790e-04 8.67683949e-05 4.33841975e-05
#  4.33841975e-05 8.67683949e-05]
# bins= [ 45.15339851  47.45838525  49.763372    52.06835874  54.37334548
#   56.67833223  58.98331897  61.28830571  63.59329246  65.8982792
#   68.20326594  70.50825269  72.81323943  75.11822617  77.42321292
#   79.72819966  82.0331864   84.33817314  86.64315989  88.94814663
#   91.25313337  93.55812012  95.86310686  98.1680936  100.47308035
#  102.77806709 105.08305383 107.38804058 109.69302732 111.99801406
#  114.30300081 116.60798755 118.91297429 121.21796103 123.52294778
#  125.82793452 128.13292126 130.43790801 132.74289475 135.04788149
#  137.35286824 139.65785498 141.96284172 144.26782847 146.57281521
#  148.87780195 151.1827887  153.48777544 155.79276218 158.09774893
#  160.40273567]

# %% [markdown]
# ## scatter

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
area = np.pi*(15*np.random.rand(N))**2

# %%
np.random.rand?

# %%
plt.scatter(x,y,s=area,c=colors,alpha=0.5)

# %% [markdown]
# ## Pie chart

# %%
labels = 'cats','birds','dogs','pandas'
sizes=[25,35,30,10]
explode=(0,0.08,0,0)#爆炸

# %%
fig1,ax1 = plt.subplots()
plt.pie(sizes,explode=explode,labels=labels,autopct='%1.1f%%',
       shadow=False,startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# ## sub-plots, radar chart

# %% [markdown]
# ## 3d

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X=np.arange(-5,5,0.25)
Y=np.arange(-5,5,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2+Y**2)
Z=np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z, rstride=1,cstride=1,cmap=cm.viridis)
plt.show()
